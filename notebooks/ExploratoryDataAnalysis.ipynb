# %% [markdown]
# # Exploratory data analysis
#
# This notebook performs an exploratory data analysis for the dataset to check
# assumptions and domain knowledge.

# %%
from german_credit import data as data_service
from german_credit import navigation as navigation_service

# %%
# docs/GermanCreditCroissant.json
URL = "https://data.openml.org/datasets/0000/0031/dataset_31.pq"
CHECKSUM = "f20f4f62ce92921ab932b78312ff68d1"

FILEPATH = navigation_service.join(
    navigation_service.to_data_dir(),
    "raw_data.parquet"
)

raw_dataset = data_service.new_dataset(
    filepath=FILEPATH,
    url=URL,
    checksum=CHECKSUM
)
